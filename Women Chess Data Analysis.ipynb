# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv(r"E:\DataAnalysisProjects-master\top_women_chess_players_aug_2020.csv")
df
# Out:
#       Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0      700070            Polgar, Judit        HUN      F         1976.0    GM
# 1     8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2     5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3     4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4      700088            Polgar, Susan        HUN      F         1969.0    GM
# ...       ...                      ...        ...    ...            ...   ...
# 8548  3302288        Reinkens, Natalia        BOL      F            NaN   NaN
# 8549   343960        Saffova, Michaela        CZE      F         1994.0   NaN
# 8550  5038294         Shetye, Siddhali        IND      F         1992.0   NaN
# 8551  2072491            Trakru, Priya        USA      F         2001.0   WFM
# 8552  4666399      Vorpahl, Sina Fleur        GER      F         1982.0   NaN
#
# ...

# %%
df.head()
# Out:
#    Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0   700070            Polgar, Judit        HUN      F         1976.0    GM
# 1  8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2  5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3  4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4   700088            Polgar, Susan        HUN      F         1969.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# 1             2658        2621.0        2601.0           NaN
# 2             2586        2483.0        2483.0           NaN
# 3             2582        2502.0        2441.0           NaN
# 4             2577           NaN           NaN            wi

# %%
#I HAD DROPED FIDE ID
df
# Out:
#                          Name Federation Gender  Year_of_birth Title  \
# 0               Polgar, Judit        HUN      F         1976.0    GM
# 1                  Hou, Yifan        CHN      F         1994.0    GM
# 2               Koneru, Humpy        IND      F         1987.0    GM
# 3     Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4               Polgar, Susan        HUN      F         1969.0    GM
# ...                       ...        ...    ...            ...   ...
# 8548        Reinkens, Natalia        BOL      F            NaN   NaN
# 8549        Saffova, Michaela        CZE      F         1994.0   NaN
# 8550         Shetye, Siddhali        IND      F         1992.0   NaN
# 8551            Trakru, Priya        USA      F         2001.0   WFM
# 8552      Vorpahl, Sina Fleur        GER      F         1982.0   NaN
#
#       Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0                2675        2646.0        2736.0            wi
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Federation            0
# Gender                0
# Year_of_birth       292
# Title              5435
# Standard_Rating       0
# Rapid_rating       4945
# Blitz_rating       5081
# Inactive_flag      2701
# dtype: int64

# %%
df.fillna('Title Unknown', inplace = True)

# %%
df
# Out:
#                          Name Federation Gender  Year_of_birth          Title  \
# 0               Polgar, Judit        HUN      F           1976             GM
# 1                  Hou, Yifan        CHN      F           1994             GM
# 2               Koneru, Humpy        IND      F           1987             GM
# 3     Goryachkina, Aleksandra        RUS      F           1998             GM
# 4               Polgar, Susan        HUN      F           1969             GM
# ...                       ...        ...    ...            ...            ...
# 8548        Reinkens, Natalia        BOL      F  Title Unknown  Title Unknown
# 8549        Saffova, Michaela        CZE      F           1994  Title Unknown
# 8550         Shetye, Siddhali        IND      F           1992  Title Unknown
# 8551            Trakru, Priya        USA      F           2001            WFM
# 8552      Vorpahl, Sina Fleur        GER      F           1982  Title Unknown
#
# ...

# %%
df.rename({'Federation':'Country'},axis=1,inplace=True)

# %%
df
# Out:
#                          Name Country Gender  Year_of_birth          Title  \
# 0               Polgar, Judit     HUN      F           1976             GM
# 1                  Hou, Yifan     CHN      F           1994             GM
# 2               Koneru, Humpy     IND      F           1987             GM
# 3     Goryachkina, Aleksandra     RUS      F           1998             GM
# 4               Polgar, Susan     HUN      F           1969             GM
# ...                       ...     ...    ...            ...            ...
# 8548        Reinkens, Natalia     BOL      F  Title Unknown  Title Unknown
# 8549        Saffova, Michaela     CZE      F           1994  Title Unknown
# 8550         Shetye, Siddhali     IND      F           1992  Title Unknown
# 8551            Trakru, Priya     USA      F           2001            WFM
# 8552      Vorpahl, Sina Fleur     GER      F           1982  Title Unknown
#
#       Standard_Rating   Rapid_rating   Blitz_rating  Inactive_flag
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
top_country = df['Country'].value_counts()
top_country.iplot(kind='bar', xTitle='Country', yTitle='Count', title='Top Countries by number of Players')
# Out:
# <div>
#
#
#             <div id="9672110e-1b5c-4b59-840a-17b0c8010c79" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9672110e-1b5c-4b59-840a-17b0c8010c79")) {
#                     Plotly.newPlot(
#                         '9672110e-1b5c-4b59-840a-17b0c8010c79',
# ...

# %%
ds=df['Title'].value_counts().reset_index()
ds.columns = ['Title', 'count']
fig = px.bar(ds, x='Title', y="count", title='Top Title ')
fig.show()
# Out:
# <div>
#
#
#             <div id="b5c397ee-4693-4292-a812-05133937ee87" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5c397ee-4693-4292-a812-05133937ee87")) {
#                     Plotly.newPlot(
#                         'b5c397ee-4693-4292-a812-05133937ee87',
#                         [{"alignmentgroup": "True", "hovertemplate": "Title=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Title Unknown", "WFM", "WIM", "WGM", "WCM", "IM", "GM", "FM", "CM", "WH"], "xaxis": "x", "y": [5435, 1545, 809, 316, 247, 119, 37, 36, 8, 1], "yaxis": "y"}],
# ...

# %%
fig = px.violin(df, y = 'Year_of_birth', title = 'Violin Distributiion of Birth Year')
fig.show()
# Out:
# <div>
#
#
#             <div id="58bd5323-c6da-4b3c-8bdf-dd88e09ebc17" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58bd5323-c6da-4b3c-8bdf-dd88e09ebc17")) {
#                     Plotly.newPlot(
#                         '58bd5323-c6da-4b3c-8bdf-dd88e09ebc17',
# ...

# %%
fig=px.density_heatmap(df,x='Standard_Rating',y='Rapid_rating')
fig.show()
# Out:
# <div>
#
#
#             <div id="99e79a13-a1e2-44d2-b32d-176b4c1858f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99e79a13-a1e2-44d2-b32d-176b4c1858f5")) {
#                     Plotly.newPlot(
#                         '99e79a13-a1e2-44d2-b32d-176b4c1858f5',
# ...

# %%
df
# Out:
#                          Name Country Gender  Year_of_birth          Title  \
# 0               Polgar, Judit     HUN      F           1976             GM
# 1                  Hou, Yifan     CHN      F           1994             GM
# 2               Koneru, Humpy     IND      F           1987             GM
# 3     Goryachkina, Aleksandra     RUS      F           1998             GM
# 4               Polgar, Susan     HUN      F           1969             GM
# ...                       ...     ...    ...            ...            ...
# 8548        Reinkens, Natalia     BOL      F  Title Unknown  Title Unknown
# 8549        Saffova, Michaela     CZE      F           1994  Title Unknown
# 8550         Shetye, Siddhali     IND      F           1992  Title Unknown
# 8551            Trakru, Priya     USA      F           2001            WFM
# 8552      Vorpahl, Sina Fleur     GER      F           1982  Title Unknown
#
#       Standard_Rating   Rapid_rating   Blitz_rating  Inactive_flag
# ...
